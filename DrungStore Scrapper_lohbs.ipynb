# %% [markdown]
# # Lohbs 상품 정보 스크래핑

# %%
# import packages
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time

# 검색 대상
search_word = "립밤"

# today's date
today = time.strftime("%y-%m-%d", time.localtime())

# %%
# target url format
url_lohbs = "https://www.lohbs.co.kr/searchEngine/search"

# %%
# 셀레니움으로 해당 페이지 정보 가져오기
driver = webdriver.Chrome("../driver/chromedriver")
driver.get(f"{url_lohbs}?keyword={search_word}")

# 해당 키워드 검색시 전체 상품 리스트를 불러오기 위한 스크롤 횟수 반환
r = driver.page_source
soup = BeautifulSoup(r, 'html.parser')
prd_num = soup.select_one(".search-page-num").string[1:-2]
scroll_num = int(prd_num) / 12 + 2
scroll_num = int(scroll_num)

# 횟수만큼 스크롤 
for i in range(scroll_num):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    
# 스크롤 완료후 페이지 소스 읽기
r = driver.page_source

# %%
# 상품별 정보 추출 및 반환
def extract_prd(html):
    img_link = html.select_one("a .prd-image img[src]")["src"]
    brand = html.select_one(".prd-content .prd-name strong").string.split("]", 1)[0][1:]
    name = html.select_one(".prd-content .prd-name strong").string.split("]", 1)[1].strip()
    if html.select_one(".prd-info .price-group .discount em") is None:
        org_price = html.select_one(".prd-info .price-group .price strong").string 
    else:
        org_price = html.select_one(".prd-info .price-group .discount em").string
    cur_price = html.select_one(".prd-info .price-group .price strong").string
    date = today
    return {
        "img_link": img_link,
        "brand": brand,
        "name": name,
        "org_price": org_price,
        "cur_price": cur_price,
        "date": today
    }

# %%
# 첫번째 상품부터 마지막 상품까지 정보 스크래핑
def extract_lohbs_prds():
    soup = BeautifulSoup(r, "html.parser")
    prd_list = soup.select_one(".layout-category-list .lohbs-prd-list")    
    prd_infos = prd_list.select("li")
    prds = []
    for prd_info in prd_infos:
        prd = extract_prd(prd_info)
        prds.append(prd)
    return prds

# %%
# 스크랩핑 결과를 DataFrame으로 변환 및 컬럼 정렬
prd_df = pd.DataFrame(extract_lohbs_prds(), columns=["date", "brand", "name", "org_price", "cur_price", "img_link"])

# 결과 확인
prd_df
# Out:
#          date    brand                     name org_price cur_price  \
# 0    19-12-08     히말라야             코코아버터 립밤 10g     3,900     3,900
# 1    19-12-08      아벤느    (1+1 기획) 시칼파트 립밤 10ml    12,600    12,600
# 2    19-12-08     멘소래담           메디케이티드 립밤 3.5g     2,700     2,700
# 3    19-12-08      아토팜       키즈 컬러 립밤 3.3g 중 택1    10,000    10,000
# 4    19-12-08     온더바디       리틀카카오 비타민E 립밤 4.5g     6,400     6,400
# 5    19-12-08       눅스          레브드미엘 립밤 15g 기획    17,000    15,300
# 6    19-12-08      허바신             우타카밀 립밤 4.8g     7,900     7,900
# 87   19-12-08      바세린            립테라피 로지립스 20g     5,200     5,200
# 88   19-12-08      바세린           립테라피 알로에베라 20g     6,500     6,500
# 89   19-12-08      니베아        립케어 후르티샤인 체리 4.8g     3,100     3,100
# 90   19-12-08     유리아쥬        스틱레브르 무향 4g 듀오 기획    16,000    16,000
# 91   19-12-08     멘소래담            딥모이스트 멘톨 4.5g     6,800     6,800
# 92   19-12-08     유리아쥬            스틱레브르 오리지널 4g    12,000    12,000
# 93   19-12-08       눅스     레브드미엘 스틱레브르 4g 듀오 기획    15,000    13,500
# 94   19-12-08      시에로                   플립 플럼퍼    13,000    13,000
# 95   19-12-08     멘소래담   딥모이스트 내추럴 4.5g   [1+1]     6,800     6,800
# 96   19-12-08      시에로         오일 플럼퍼 ♥ 윤은혜 립스틱     9,000     9,000
# 97   19-12-08    파파야골드                 포포크림 25g     6,500     6,500
# 98   19-12-08     부르조아                    벨벳 펜슬    23,000    23,000
# 99   19-12-08      니베아          팝볼 라즈베리&레드애플 7g     7,900     7,900
# 100  19-12-08      레브론             울트라 HD 젤 립컬러    12,600    12,600
# 101  19-12-08    파파야골드                포포크림 100g    19,000    19,000
# 102  19-12-08     다슈포맨            맨즈 퍼펙트 커버 컨실러    12,000    12,000
# 103  19-12-08       미프    배틀그라운드 올인원 파워 립 엔진 세트    19,800    19,800
# 104  19-12-08     아임미미          아임 틱톡 틴트 립 캐시미어    15,000    15,000
# 105  19-12-08     멘소래담                       립팟     4,100     4,100
# 106  19-12-08  네이크업페이스                  원나잇 립스틱    11,000    11,000
#
#                                               img_link
# 0    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 1    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 2    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 3    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 4    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 5    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 6    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 7    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 8    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 9    https://www.lohbs.co.kr/lohbsUpload/productIma...
# 10   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 11   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 12   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 13   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 14   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 15   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 16   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 17   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 18   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 19   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 20   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 21   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 22   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 23   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 24   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 25   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 26   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 27   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 28   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 29   https://www.lohbs.co.kr/lohbsUpload/productIma...
# ..                                                 ...
# 77   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 78   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 79   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 80   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 81   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 82   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 83   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 84   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 85   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 86   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 87   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 88   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 89   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 90   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 91   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 92   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 93   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 94   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 95   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 96   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 97   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 98   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 99   https://www.lohbs.co.kr/lohbsUpload/productIma...
# 100  https://www.lohbs.co.kr/lohbsUpload/productIma...
# 101  https://www.lohbs.co.kr/lohbsUpload/productIma...
# 102  https://www.lohbs.co.kr/lohbsUpload/productIma...
# 103  https://www.lohbs.co.kr/lohbsUpload/productIma...
# 104  https://www.lohbs.co.kr/lohbsUpload/productIma...
# 105  https://www.lohbs.co.kr/lohbsUpload/productIma...
# 106  https://www.lohbs.co.kr/lohbsUpload/productIma...
#
# [107 rows x 6 columns]
